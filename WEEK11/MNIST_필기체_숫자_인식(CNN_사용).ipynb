# %%
# 라이브러리 불러오기

import tensorflow as tf
from tensorflow.keras import datasets, layers, models

# %%
# MNIST 데이터셋 로드
# train_images : 학습용 이미지
# train_labels : 학습용 정답
# test_images  : 테스트용 이미지
# test_labels  : 테스트용 정답

(train_images, train_labels), (test_images, test_labels) = datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# 이미지 형태 변환

# reshape:
# CNN 입력 형식에 맞게 변환
# (샘플 수, 높이, 너비, 채널 수)
# MNIST는 흑백 이미지이므로 채널 수 = 1

train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))

# %%
# 이미지 정규화

# 이미지 데이터를 float32 타입으로 변환
# 픽셀값을 0~255 -> 0~1 사이로 변환

train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
# Sequential 방식 CNN 모델 생성
model = models.Sequential()

# %%
# 첫 번째 컨벌루션 층

# Conv2D:
# 이미지 특징 추출

# 32:
# 필터 개수 32개

# (3,3):
# 3x3 필터 사용

# relu:
# 활성화 함수

# input_shape:
# 입력 이미지 크기
# 28x28 흑백 이미지

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 첫 번째 풀링 층

# 이미지 크기 축소
# 중요한 특징만 남김

model.add(layers.MaxPooling2D((2, 2)))

# %%
# 두 번째 컨벌루션 층

# 더 복잡한 특징 추출

model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %%
# 두 번째 풀링 층

# 다시 크기 축소

model.add(layers.MaxPooling2D((2, 2)))

# %%
# 세 번째 컨벌루션 층

# 더 깊은 특징 추출

model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# %%
# Flatten 층

# 2차원 특징맵을
# 1차원 벡터로 변환

model.add(layers.Flatten())

# %%
# Dense 층

# 완전 연결층

model.add(layers.Dense(64, activation='relu'))

# %%
# 출력층

# 0~9 숫자 다중 분류

# 출력 뉴런 10개
# softmax 사용

model.add(layers.Dense(10, activation='softmax'))

# %%
# 모델 구조 확인
# CNN 구조 출력

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 3, 3, 64)       │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 576)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 93,322 (364.54 KB)
#  Trainable params: 93,322 (364.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 모델 컴파일

# optimizer:
# 가중치 업데이트 방법

# sparse_categorical_crossentropy:
# 다중 분류용 손실 함수

# accuracy:
# 정확도 출력

model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=['accuracy'])

# %%
# CNN 학습

# epochs=5:
# 전체 데이터를 5번 반복 학습

model.fit(train_images, train_labels, epochs=5)

# 모델 평가

# 테스트 데이터 평가

test_loss, test_acc = model.evaluate(test_images, test_labels)

print("테스트 정확도:", test_acc)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 57s 29ms/step - accuracy: 0.9549 - loss: 0.1490
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9860 - loss: 0.0460
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 86s 29ms/step - accuracy: 0.9901 - loss: 0.0321
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9924 - loss: 0.0243
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 51s 27ms/step - accuracy: 0.9938 - loss: 0.0195
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9915 - loss: 0.0276
# 테스트 정확도: 0.9915000200271606
